# %%
import openeo

# Connection and authentication
con = openeo.connect("openeo.dataspace.copernicus.eu")
con.authenticate_oidc()

# Definition of the region 
spatial_extent = {"west": -6.25, "south": 42.27, "east": -6.16, "north": 42.36 ,"crs": "EPSG:4326",}
year = '2023'

temporal_extent = [year+"-01-01", year+"-12-31"]
datacube = con.load_collection(
    "SENTINEL2_L2A",
    spatial_extent=spatial_extent,
    temporal_extent=temporal_extent,
    max_cloud_cover=10,
    bands=["B04", "B03", "B02", "B08", "SCL"],
)

download_path = 'seasons/sentinel2_' +year+'.nc'
datacube.download(download_path)
# Out:
# Authenticated using refresh token.

# %%
import xarray
import matplotlib.pyplot as plt

ds = xarray.load_dataset('seasons/sentinel2_'+year+'.nc')

# Convert xarray DataSet to a (bands, t, x, y) DataArray
data = ds[["B04", "B03", "B02"]].to_array(dim="bands")

fig, axes = plt.subplots(ncols=2, figsize=(8, 3), dpi=300, sharey=True)
data[{"t": 0}].plot.imshow(vmin=0, vmax=2000, ax=axes[0])
data[{"t": -1}].plot.imshow(vmin=0, vmax=2000, ax=axes[1]);
# Out:
# /home/bea/.local/lib/python3.10/site-packages/matplotlib/cm.py:494: RuntimeWarning: invalid value encountered in cast
#   xx = (xx * 255).astype(np.uint8)

# %%
# SPRING
spring = datacube.filter_temporal(year+"-03-01", year+"-05-31")
path = 'seasons/spring/sentinel2_' +year+ '_3-5.nc'
spring.download(path)

ds = xarray.load_dataset(path)

# Convert xarray DataSet to a (bands, t, x, y) DataArray
data = ds[["B04", "B03", "B02"]].to_array(dim="bands")

fig, axes = plt.subplots(ncols=2, figsize=(8, 3), dpi=300, sharey=True)
data[{"t": 0}].plot.imshow(vmin=0, vmax=2000, ax=axes[0])
data[{"t": -1}].plot.imshow(vmin=0, vmax=2000, ax=axes[1]);

# %%
# SUMMER
summer = datacube.filter_temporal(year+"-06-01", year+"-08-31")
path = 'seasons/summer/sentinel2_' +year+ '_6-8.nc'
summer.download(path)

ds = xarray.load_dataset(path)

# Convert xarray DataSet to a (bands, t, x, y) DataArray
data = ds[["B04", "B03", "B02"]].to_array(dim="bands")

fig, axes = plt.subplots(ncols=2, figsize=(8, 3), dpi=300, sharey=True)
data[{"t": 0}].plot.imshow(vmin=0, vmax=2000, ax=axes[0])
data[{"t": -1}].plot.imshow(vmin=0, vmax=2000, ax=axes[1]);

# %%
# AUTUMN
autumn = datacube.filter_temporal(year+"-09-01", year+"-11-30")
path = 'seasons/autumn/sentinel2_' +year+ '_9-11.nc'
autumn.download(path)

ds = xarray.load_dataset(path)

# Convert xarray DataSet to a (bands, t, x, y) DataArray
data = ds[["B04", "B03", "B02"]].to_array(dim="bands")

fig, axes = plt.subplots(ncols=2, figsize=(8, 3), dpi=300, sharey=True)
data[{"t": 0}].plot.imshow(vmin=0, vmax=2000, ax=axes[0])
data[{"t": -1}].plot.imshow(vmin=0, vmax=2000, ax=axes[1]);

# %%
# WINTER
#january - february
winter = datacube.filter_temporal(year+"-01-01", year+"-02-28")
path = 'seasons/winter/sentinel2_' +year+ '_1-2.nc'
winter.download(path)

ds = xarray.load_dataset(path)

# Convert xarray DataSet to a (bands, t, x, y) DataArray
data = ds[["B04", "B03", "B02"]].to_array(dim="bands")

fig, axes = plt.subplots(ncols=2, figsize=(8, 3), dpi=300, sharey=True)
data[{"t": 0}].plot.imshow(vmin=0, vmax=2000, ax=axes[0])
data[{"t": -1}].plot.imshow(vmin=0, vmax=2000, ax=axes[1]);
# Out:
# /home/bea/.local/lib/python3.10/site-packages/matplotlib/cm.py:494: RuntimeWarning: invalid value encountered in cast
#   xx = (xx * 255).astype(np.uint8)

# %%
# WINTER
#december
winter = datacube.filter_temporal(year+"-12-01", year+"-12-31")
path = 'seasons/winter/sentinel2_' +year+ '_12.nc'
winter.download(path)

ds = xarray.load_dataset(path)

# Convert xarray DataSet to a (bands, t, x, y) DataArray
data = ds[["B04", "B03", "B02"]].to_array(dim="bands")

fig, axes = plt.subplots(ncols=2, figsize=(8, 3), dpi=300, sharey=True)
data[{"t": 0}].plot.imshow(vmin=0, vmax=2000, ax=axes[0])
data[{"t": -1}].plot.imshow(vmin=0, vmax=2000, ax=axes[1]);
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# ...
